# %% [markdown]
# # Code: Global pairwise alignments
#
# We will now to make use of our definitions of a Needleman-Wunsch alignment to see how the algorithm transforms to actual code. The sections below will walk you through how this is done.

# %% [markdown]
# ```{toggle}
# To facilitate the the reasoning in the subsequent cells, we first we define a couple of service functions that we will need later, for formating and printing alignments. It is not important that you understand what these functions do, for now.
# ```

# %%
import numpy as np

# Print 2 sequences on top of each other
def print_alignment(seqA,seqB):
    print(seqA)
    print(seqB)

def traceback_alignment_latex(seqA, seqB, scores, traceback):
    """
    Generates LaTeX code for the matrix with traceback arrows.
    
    Parameters:
        seqA (str): First sequence.
        seqB (str): Second sequence.
        scores (numpy array): Score matrix.
        traceback (dict): Traceback matrix.
        
    Returns:
        latex_code (str): LaTeX code for the matrix with traceback arrows.
    """
    seqA, seqB = "-" + seqA, "-" + seqB
    nrows = len(seqA)
    ncols = len(seqB)
    latex_code = ""
        
    # Draw arrows for traceback paths
    def backtrack_latex(i, j):
        latex_code = ""
        for di, dj in traceback.get((i, j), []):
            ni, nj = i + di, j + dj
            if di == -1 and dj == -1:  # Diagonal arrow
                latex_code += f"\\draw [blue,very thick,->] ({j + 1.3},{nrows - i - 1.2}) -- ({j + 0.9},{nrows - i - 0.8});\n"
            elif di == -1:  # Upward arrow
                latex_code += f"\\draw [blue,very thick,->] ({j + 1.6},{nrows - i - 1.2}) -- ({j + 1.6},{nrows - i - 0.8});\n"
            elif dj == -1:  # Leftward arrow
                latex_code += f"\\draw [blue,very thick,->] ({j + 1.2},{nrows - i - 1.4}) -- ({j + 0.8},{nrows - i - 1.4});\n"                
            else:  # Stop
                return latex_code                
            latex_code += backtrack_latex(ni, nj)
        return latex_code
    
    # Start traceback from the bottom-right corner
    latex_code += backtrack_latex(nrows - 2, ncols - 2)
        
    return latex_code


# Format an alignment by inserting gaps in sequences
def format_alignment(seqA,seqB,S,trace):
    print("Best score: " + str(S[-1,-1]))
    outA,outB = "",""
    i,j = len(seqA),len(seqB)
    while i>0 or j>0:
        print(i,j,trace[(i,j)])
        di,dj = trace[(i,j)]
        i += int(di)
        j += int(dj)
        if di == 0:
            outA = "-" + outA
        else:
            outA = seqA[i] + outA
        if dj == 0:
            outB = "-" + outB
        else:
            outB = seqB[j] + outB
    return outA,outB

# %%
# redefine print statement so that it prints latex code
def print_dynamic(seqA, seqB, dpm, trace):
    """
    Generates LaTeX code for a matrix representation of the pairwise alignment.
    
    Parameters:
    - seqA: The first sequence (e.g., "GAC")
    - seqB: The second sequence (e.g., "ACG")
    - dpm: A 2D list or numpy array containing the alignment scores.
    - trace: A dictionary or 2D array where each element is a tuple (di, dj) indicating the direction of the path.
    
    Returns:
    - A string containing the LaTeX code.
    """
    seqA, seqB = "-" + seqA, "-" + seqB
    nrows = len(seqA)
    ncols = len(seqB)
    
    latex_code = "\\begin{tikzpicture}[set style={{help lines}+=[dashed]}, xscale=1.0, yscale=1]\n\n"
    latex_code += f"\\draw (1,0) grid +({ncols},{nrows});\n\n"
    
    # Labels for sequences
    for i, letter in enumerate(seqA):
        latex_code += f"\\node  at  (0.5, {nrows - i - 0.5}) {{{letter}}};\n"
    for j, letter in enumerate(seqB):
        latex_code += f"\\node  at  ({j + 1.5}, {nrows + 0.5}) {{{letter}}};\n"
    
    latex_code += "\n"
    
    # Fill matrix values and draw arrows if applicable
    for i in range(nrows):
        for j in range(ncols):
            value = dpm[i][j]
            latex_code += f"\\node  at  ({j + 1.5}, {nrows - i - 0.5}) {{{value}}};\n"
            if (i,j) in trace:
                for di, dj in trace[(i, j)]:
                    ii, jj = i+di, j+dj
                    #ii, jj = i, j
                    if di == -1 and dj == -1:
                        latex_code += f"\\draw   [red,very thick,dashed,->]   ({jj + 1.8},{nrows - ii - 0.8}) -- ({jj + 2.2},{nrows - ii - 1.2});\n"
                    elif di == -1 and dj == 0:
                        latex_code += f"\\draw   [red,very thick,dashed,->]   ({jj + 1.5},{nrows - ii - 0.8}) -- ({jj + 1.5},{nrows - ii - 1.2});\n"
                    elif di == 0 and dj == -1:
                        latex_code += f"\\draw   [red,very thick,dashed,->]   ({jj + 1.8},{nrows - ii - 0.5}) -- ({jj + 2.2},{nrows - ii - 0.5});\n"
                    elif di == 0 and dj == 0:
                        latex_code += f"\\draw   [red,very thick]   ({jj + 1.2},{nrows - ii - 0.2}) -- ({jj + 1.2},{nrows - ii - 0.3});\n"
    
    latex_code += traceback_alignment_latex(seqA, seqB, dpm, trace)
    latex_code += "\\end{tikzpicture}\n"
    
    print(latex_code)

# %% [markdown]
# ## Scoring system for DNA sequences
# We setup the scoring system we need for the alignment of DNA sequences. Here we use a score system where gaps score -2 and miss matches are scored -1 and matches get a score of 3. You should absolutly try to change the scoring function at some point to see how the values affects the alignments.

# %%
def gap_penalty():
    return -2.0

def match_score(letterA,letterB):
    if letterA == '-' or letterB == '-':
        return gap_penalty()
    elif letterA == letterB:
        return 3.0
    else:
        return -1.0

# %% [markdown]
# ## Global alignments by Needleman-Wunsch
# Here follows an implementation of the [Needleman-Wunsch](http://www.sciencedirect.com/science/article/pii/0022283670900574) pairwise alignment method.  We want to align two sequences $a=a_1,\ldots,a_{M}$ and $b=b_1,\ldots,b_{N}$.
#
# As said in last chapter, the dynamic programming matrix $S$ is initiated as:
# $S_{i0}=g \cdot i, \forall i,$
# $S_{0j}=g \cdot j, \forall j$
#
# This translates easy into two for loops filling in the upper row and the leftmost column.
#
# Here we als initiate pointers in the form of a trace matrix. Each element in the trace matrix contains the difference in index between the current cell and the optimal step that lead to the current cell.

# %%
# Initiating dynamic programming matrices, S and trace
def initiate_global_dp(m,n):
    S = np.zeros((m,n))       # An m*n matrix, initiated with 0's
    trace = {}
    S[0,0] = 0.
    trace[(0,0)] = [(0.,0.)]
    for i in range(1,m):
        S[i,0] = i * gap_penalty()
        trace[(i,0)] =[(-1,0)]
    for j in range(1,n):
        S[0,j] = j * gap_penalty()
        trace[(0,j)] =[(0,-1)]
    return S,trace

# %% [markdown]
# Subsequently, the rest of $S$ is filled as:
# $S_{ij}=\max\left\{
# \begin{array}{ll}
# S_{i-1,j-1} & +d(a_i,b_j)\\
# S_{i-1,j} & +d(a_i,-)\\
# S_{i,j-1} & +d(-,b_j)
# \end{array}
# \right.$
#
# This recursion is easily transformed into for-loops. We are free to select the order the matrix is filled in so we select to fill in row per row, i.e. rows become the inner loop, the columns the outer loop.
#
# Ahgain we keep track of the move that lead to a certain position by filling in the `trace` matrix.

# %%
def global_align(seqA,seqB,print_dynamic_matrix = False):
    # Initiating variables
    m, n = len(seqA)+1, len(seqB)+1
    S,trace = initiate_global_dp(m,n)
    # Fill in the rest of the dynamic programming matrix
    for i in range(1,m):
        for j in range(1,n):
            # Note the subtraction of 1 for the sequence position
            # In python sequences are indexed from 0 to len-1
            match = S[i-1,j-1] + match_score(seqA[i-1],seqB[j-1]) 
            delete = S[i-1,j] + match_score(seqA[i-1],'-') 
            insert = S[i,j-1] + match_score('-',seqB[j-1]) 
            S[i,j] = max(match,delete,insert)
            trace[(i,j)] = [] 
            if match == S[i,j]:
                trace[(i,j)].append((-1,-1)) 
            if delete == S[i,j]:
                trace[(i,j)].append((-1,0)) 
            if insert == S[i,j]:
                trace[(i,j)].append((0,-1))
    if print_dynamic_matrix:
        print_dynamic(seqA,seqB,S,trace)
    return

# %% [markdown]
# Now everything is set. We can try the code for any of our favorite sequences. One can toggle the printout of the dynamic programming matrix by a boolean flag as a third argument.

# %%
global_align("GATTA","GCTAC",True)
# Out:
# \begin{tikzpicture}[set style={{help lines}+=[dashed]}, xscale=1.0, yscale=1]
#
# \draw (1,0) grid +(6,6);
#
# \node  at  (0.5, 5.5) {-};
# \node  at  (0.5, 4.5) {G};
# \node  at  (0.5, 3.5) {A};
# \node  at  (0.5, 2.5) {T};
# \node  at  (0.5, 1.5) {T};
# \node  at  (0.5, 0.5) {A};
# \node  at  (1.5, 6.5) {-};
# \node  at  (2.5, 6.5) {G};
# \node  at  (3.5, 6.5) {C};
# \node  at  (4.5, 6.5) {T};
# \node  at  (5.5, 6.5) {A};
# \node  at  (6.5, 6.5) {C};
#
# \node  at  (1.5, 5.5) {0.0};
# \draw   [red,very thick]   (1.2,5.8) -- (1.2,5.7);
# \node  at  (2.5, 5.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (1.8,5.5) -- (2.2,5.5);
# \node  at  (3.5, 5.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (2.8,5.5) -- (3.2,5.5);
# \node  at  (4.5, 5.5) {-6.0};
# \draw   [red,very thick,dashed,->]   (3.8,5.5) -- (4.2,5.5);
# \node  at  (5.5, 5.5) {-8.0};
# \draw   [red,very thick,dashed,->]   (4.8,5.5) -- (5.2,5.5);
# \node  at  (6.5, 5.5) {-10.0};
# \draw   [red,very thick,dashed,->]   (5.8,5.5) -- (6.2,5.5);
# \node  at  (1.5, 4.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (1.5,5.2) -- (1.5,4.8);
# \node  at  (2.5, 4.5) {3.0};
# \draw   [red,very thick,dashed,->]   (1.8,5.2) -- (2.2,4.8);
# \node  at  (3.5, 4.5) {1.0};
# \draw   [red,very thick,dashed,->]   (2.8,4.5) -- (3.2,4.5);
# \node  at  (4.5, 4.5) {-1.0};
# \draw   [red,very thick,dashed,->]   (3.8,4.5) -- (4.2,4.5);
# \node  at  (5.5, 4.5) {-3.0};
# \draw   [red,very thick,dashed,->]   (4.8,4.5) -- (5.2,4.5);
# \node  at  (6.5, 4.5) {-5.0};
# \draw   [red,very thick,dashed,->]   (5.8,4.5) -- (6.2,4.5);
# \node  at  (1.5, 3.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (1.5,4.2) -- (1.5,3.8);
# \node  at  (2.5, 3.5) {1.0};
# \draw   [red,very thick,dashed,->]   (2.5,4.2) -- (2.5,3.8);
# \node  at  (3.5, 3.5) {2.0};
# \draw   [red,very thick,dashed,->]   (2.8,4.2) -- (3.2,3.8);
# \node  at  (4.5, 3.5) {0.0};
# \draw   [red,very thick,dashed,->]   (3.8,4.2) -- (4.2,3.8);
# \draw   [red,very thick,dashed,->]   (3.8,3.5) -- (4.2,3.5);
# \node  at  (5.5, 3.5) {2.0};
# \draw   [red,very thick,dashed,->]   (4.8,4.2) -- (5.2,3.8);
# \node  at  (6.5, 3.5) {0.0};
# \draw   [red,very thick,dashed,->]   (5.8,3.5) -- (6.2,3.5);
# \node  at  (1.5, 2.5) {-6.0};
# \draw   [red,very thick,dashed,->]   (1.5,3.2) -- (1.5,2.8);
# \node  at  (2.5, 2.5) {-1.0};
# \draw   [red,very thick,dashed,->]   (2.5,3.2) -- (2.5,2.8);
# \node  at  (3.5, 2.5) {0.0};
# \draw   [red,very thick,dashed,->]   (2.8,3.2) -- (3.2,2.8);
# \draw   [red,very thick,dashed,->]   (3.5,3.2) -- (3.5,2.8);
# \node  at  (4.5, 2.5) {5.0};
# \draw   [red,very thick,dashed,->]   (3.8,3.2) -- (4.2,2.8);
# \node  at  (5.5, 2.5) {3.0};
# \draw   [red,very thick,dashed,->]   (4.8,2.5) -- (5.2,2.5);
# \node  at  (6.5, 2.5) {1.0};
# \draw   [red,very thick,dashed,->]   (5.8,3.2) -- (6.2,2.8);
# \draw   [red,very thick,dashed,->]   (5.8,2.5) -- (6.2,2.5);
# \node  at  (1.5, 1.5) {-8.0};
# \draw   [red,very thick,dashed,->]   (1.5,2.2) -- (1.5,1.8);
# \node  at  (2.5, 1.5) {-3.0};
# \draw   [red,very thick,dashed,->]   (2.5,2.2) -- (2.5,1.8);
# \node  at  (3.5, 1.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (2.8,2.2) -- (3.2,1.8);
# \draw   [red,very thick,dashed,->]   (3.5,2.2) -- (3.5,1.8);
# \node  at  (4.5, 1.5) {3.0};
# \draw   [red,very thick,dashed,->]   (3.8,2.2) -- (4.2,1.8);
# \draw   [red,very thick,dashed,->]   (4.5,2.2) -- (4.5,1.8);
# \node  at  (5.5, 1.5) {4.0};
# \draw   [red,very thick,dashed,->]   (4.8,2.2) -- (5.2,1.8);
# \node  at  (6.5, 1.5) {2.0};
# \draw   [red,very thick,dashed,->]   (5.8,2.2) -- (6.2,1.8);
# \draw   [red,very thick,dashed,->]   (5.8,1.5) -- (6.2,1.5);
# \node  at  (1.5, 0.5) {-10.0};
# \draw   [red,very thick,dashed,->]   (1.5,1.2) -- (1.5,0.8);
# \node  at  (2.5, 0.5) {-5.0};
# \draw   [red,very thick,dashed,->]   (2.5,1.2) -- (2.5,0.8);
# \node  at  (3.5, 0.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (2.8,1.2) -- (3.2,0.8);
# \draw   [red,very thick,dashed,->]   (3.5,1.2) -- (3.5,0.8);
# \node  at  (4.5, 0.5) {1.0};
# \draw   [red,very thick,dashed,->]   (4.5,1.2) -- (4.5,0.8);
# \node  at  (5.5, 0.5) {6.0};
# \draw   [red,very thick,dashed,->]   (4.8,1.2) -- (5.2,0.8);
# \node  at  (6.5, 0.5) {4.0};
# \draw   [red,very thick,dashed,->]   (5.8,0.5) -- (6.2,0.5);
# \draw [blue,very thick,->] (6.2,0.6000000000000001) -- (5.8,0.6000000000000001);
# \draw [blue,very thick,->] (5.3,0.8) -- (4.9,1.2);
# \draw [blue,very thick,->] (4.3,1.8) -- (3.9,2.2);
# \draw [blue,very thick,->] (3.3,2.8) -- (2.9,3.2);
# \draw [blue,very thick,->] (2.6,3.8) -- (2.6,4.2);
# \draw [blue,very thick,->] (2.3,4.8) -- (1.9,5.2);
# \draw [blue,very thick,->] (3.6,2.8) -- (3.6,3.2);
# \draw [blue,very thick,->] (3.3,3.8) -- (2.9,4.2);
# \draw [blue,very thick,->] (2.3,4.8) -- (1.9,5.2);
# \draw [blue,very thick,->] (4.6,1.8) -- (4.6,2.2);
# \draw [blue,very thick,->] (4.3,2.8) -- (3.9,3.2);
# \draw [blue,very thick,->] (3.3,3.8) -- (2.9,4.2);
# \draw [blue,very thick,->] (2.3,4.8) -- (1.9,5.2);
# \end{tikzpicture}

# %% [markdown]
# I add a couple of extra alignments, check them manually as an excercise before the exam. Also try to run a couple of them yourself.

# %%
global_align("GCAGCTA","GCTA",True)
# Out:
# \begin{tikzpicture}[set style={{help lines}+=[dashed]}, xscale=1.0, yscale=1]
#
# \draw (1,0) grid +(5,8);
#
# \node  at  (0.5, 7.5) {-};
# \node  at  (0.5, 6.5) {G};
# \node  at  (0.5, 5.5) {C};
# \node  at  (0.5, 4.5) {A};
# \node  at  (0.5, 3.5) {G};
# \node  at  (0.5, 2.5) {C};
# \node  at  (0.5, 1.5) {T};
# \node  at  (0.5, 0.5) {A};
# \node  at  (1.5, 8.5) {-};
# \node  at  (2.5, 8.5) {G};
# \node  at  (3.5, 8.5) {C};
# \node  at  (4.5, 8.5) {T};
# \node  at  (5.5, 8.5) {A};
#
# \node  at  (1.5, 7.5) {0.0};
# \draw   [red,very thick]   (1.2,7.8) -- (1.2,7.7);
# \node  at  (2.5, 7.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (1.8,7.5) -- (2.2,7.5);
# \node  at  (3.5, 7.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (2.8,7.5) -- (3.2,7.5);
# \node  at  (4.5, 7.5) {-6.0};
# \draw   [red,very thick,dashed,->]   (3.8,7.5) -- (4.2,7.5);
# \node  at  (5.5, 7.5) {-8.0};
# \draw   [red,very thick,dashed,->]   (4.8,7.5) -- (5.2,7.5);
# \node  at  (1.5, 6.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (1.5,7.2) -- (1.5,6.8);
# \node  at  (2.5, 6.5) {3.0};
# \draw   [red,very thick,dashed,->]   (1.8,7.2) -- (2.2,6.8);
# \node  at  (3.5, 6.5) {1.0};
# \draw   [red,very thick,dashed,->]   (2.8,6.5) -- (3.2,6.5);
# \node  at  (4.5, 6.5) {-1.0};
# \draw   [red,very thick,dashed,->]   (3.8,6.5) -- (4.2,6.5);
# \node  at  (5.5, 6.5) {-3.0};
# \draw   [red,very thick,dashed,->]   (4.8,6.5) -- (5.2,6.5);
# \node  at  (1.5, 5.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (1.5,6.2) -- (1.5,5.8);
# \node  at  (2.5, 5.5) {1.0};
# \draw   [red,very thick,dashed,->]   (2.5,6.2) -- (2.5,5.8);
# \node  at  (3.5, 5.5) {6.0};
# \draw   [red,very thick,dashed,->]   (2.8,6.2) -- (3.2,5.8);
# \node  at  (4.5, 5.5) {4.0};
# \draw   [red,very thick,dashed,->]   (3.8,5.5) -- (4.2,5.5);
# \node  at  (5.5, 5.5) {2.0};
# \draw   [red,very thick,dashed,->]   (4.8,5.5) -- (5.2,5.5);
# \node  at  (1.5, 4.5) {-6.0};
# \draw   [red,very thick,dashed,->]   (1.5,5.2) -- (1.5,4.8);
# \node  at  (2.5, 4.5) {-1.0};
# \draw   [red,very thick,dashed,->]   (2.5,5.2) -- (2.5,4.8);
# \node  at  (3.5, 4.5) {4.0};
# \draw   [red,very thick,dashed,->]   (3.5,5.2) -- (3.5,4.8);
# \node  at  (4.5, 4.5) {5.0};
# \draw   [red,very thick,dashed,->]   (3.8,5.2) -- (4.2,4.8);
# \node  at  (5.5, 4.5) {7.0};
# \draw   [red,very thick,dashed,->]   (4.8,5.2) -- (5.2,4.8);
# \node  at  (1.5, 3.5) {-8.0};
# \draw   [red,very thick,dashed,->]   (1.5,4.2) -- (1.5,3.8);
# \node  at  (2.5, 3.5) {-3.0};
# \draw   [red,very thick,dashed,->]   (1.8,4.2) -- (2.2,3.8);
# \draw   [red,very thick,dashed,->]   (2.5,4.2) -- (2.5,3.8);
# \node  at  (3.5, 3.5) {2.0};
# \draw   [red,very thick,dashed,->]   (3.5,4.2) -- (3.5,3.8);
# \node  at  (4.5, 3.5) {3.0};
# \draw   [red,very thick,dashed,->]   (3.8,4.2) -- (4.2,3.8);
# \draw   [red,very thick,dashed,->]   (4.5,4.2) -- (4.5,3.8);
# \node  at  (5.5, 3.5) {5.0};
# \draw   [red,very thick,dashed,->]   (5.5,4.2) -- (5.5,3.8);
# \node  at  (1.5, 2.5) {-10.0};
# \draw   [red,very thick,dashed,->]   (1.5,3.2) -- (1.5,2.8);
# \node  at  (2.5, 2.5) {-5.0};
# \draw   [red,very thick,dashed,->]   (2.5,3.2) -- (2.5,2.8);
# \node  at  (3.5, 2.5) {0.0};
# \draw   [red,very thick,dashed,->]   (2.8,3.2) -- (3.2,2.8);
# \draw   [red,very thick,dashed,->]   (3.5,3.2) -- (3.5,2.8);
# \node  at  (4.5, 2.5) {1.0};
# \draw   [red,very thick,dashed,->]   (3.8,3.2) -- (4.2,2.8);
# \draw   [red,very thick,dashed,->]   (4.5,3.2) -- (4.5,2.8);
# \node  at  (5.5, 2.5) {3.0};
# \draw   [red,very thick,dashed,->]   (5.5,3.2) -- (5.5,2.8);
# \node  at  (1.5, 1.5) {-12.0};
# \draw   [red,very thick,dashed,->]   (1.5,2.2) -- (1.5,1.8);
# \node  at  (2.5, 1.5) {-7.0};
# \draw   [red,very thick,dashed,->]   (2.5,2.2) -- (2.5,1.8);
# \node  at  (3.5, 1.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (3.5,2.2) -- (3.5,1.8);
# \node  at  (4.5, 1.5) {3.0};
# \draw   [red,very thick,dashed,->]   (3.8,2.2) -- (4.2,1.8);
# \node  at  (5.5, 1.5) {1.0};
# \draw   [red,very thick,dashed,->]   (5.5,2.2) -- (5.5,1.8);
# \draw   [red,very thick,dashed,->]   (4.8,1.5) -- (5.2,1.5);
# \node  at  (1.5, 0.5) {-14.0};
# \draw   [red,very thick,dashed,->]   (1.5,1.2) -- (1.5,0.8);
# \node  at  (2.5, 0.5) {-9.0};
# \draw   [red,very thick,dashed,->]   (2.5,1.2) -- (2.5,0.8);
# \node  at  (3.5, 0.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (3.5,1.2) -- (3.5,0.8);
# \node  at  (4.5, 0.5) {1.0};
# \draw   [red,very thick,dashed,->]   (4.5,1.2) -- (4.5,0.8);
# \node  at  (5.5, 0.5) {6.0};
# \draw   [red,very thick,dashed,->]   (4.8,1.2) -- (5.2,0.8);
# \draw [blue,very thick,->] (5.3,0.8) -- (4.9,1.2);
# \draw [blue,very thick,->] (4.3,1.8) -- (3.9,2.2);
# \draw [blue,very thick,->] (3.3,2.8) -- (2.9,3.2);
# \draw [blue,very thick,->] (2.3,3.8) -- (1.9,4.2);
# \draw [blue,very thick,->] (1.6,4.8) -- (1.6,5.2);
# \draw [blue,very thick,->] (1.6,5.8) -- (1.6,6.2);
# \draw [blue,very thick,->] (1.6,6.8) -- (1.6,7.2);
# \draw [blue,very thick,->] (2.6,3.8) -- (2.6,4.2);
# \draw [blue,very thick,->] (2.6,4.8) -- (2.6,5.2);
# \draw [blue,very thick,->] (2.6,5.8) -- (2.6,6.2);
# \draw [blue,very thick,->] (2.3,6.8) -- (1.9,7.2);
# \draw [blue,very thick,->] (3.6,2.8) -- (3.6,3.2);
# \draw [blue,very thick,->] (3.6,3.8) -- (3.6,4.2);
# \draw [blue,very thick,->] (3.6,4.8) -- (3.6,5.2);
# \draw [blue,very thick,->] (3.3,5.8) -- (2.9,6.2);
# \draw [blue,very thick,->] (2.3,6.8) -- (1.9,7.2);
# \end{tikzpicture}

# %%
seqA,seqB = global_align("CTATCTCGCTATCCA","CTACGCTATTTCA",True)
print_alignment(seqA,seqB)
# Out:
# \begin{tikzpicture}[set style={{help lines}+=[dashed]}, xscale=1.0, yscale=1]
#
# \draw (1,0) grid +(14,16);
#
# \node  at  (0.5, 15.5) {-};
# \node  at  (0.5, 14.5) {C};
# \node  at  (0.5, 13.5) {T};
# \node  at  (0.5, 12.5) {A};
# \node  at  (0.5, 11.5) {T};
# \node  at  (0.5, 10.5) {C};
# \node  at  (0.5, 9.5) {T};
# \node  at  (0.5, 8.5) {C};
# \node  at  (0.5, 7.5) {G};
# \node  at  (0.5, 6.5) {C};
# \node  at  (0.5, 5.5) {T};
# \node  at  (0.5, 4.5) {A};
# \node  at  (0.5, 3.5) {T};
# \node  at  (0.5, 2.5) {C};
# \node  at  (0.5, 1.5) {C};
# \node  at  (0.5, 0.5) {A};
# \node  at  (1.5, 16.5) {-};
# \node  at  (2.5, 16.5) {C};
# \node  at  (3.5, 16.5) {T};
# \node  at  (4.5, 16.5) {A};
# \node  at  (5.5, 16.5) {C};
# \node  at  (6.5, 16.5) {G};
# \node  at  (7.5, 16.5) {C};
# \node  at  (8.5, 16.5) {T};
# \node  at  (9.5, 16.5) {A};
# \node  at  (10.5, 16.5) {T};
# \node  at  (11.5, 16.5) {T};
# \node  at  (12.5, 16.5) {T};
# \node  at  (13.5, 16.5) {C};
# \node  at  (14.5, 16.5) {A};
#
# \node  at  (1.5, 15.5) {0.0};
# \draw   [red,very thick]   (1.2,15.8) -- (1.2,15.7);
# \node  at  (2.5, 15.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (1.8,15.5) -- (2.2,15.5);
# \node  at  (3.5, 15.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (2.8,15.5) -- (3.2,15.5);
# \node  at  (4.5, 15.5) {-6.0};
# \draw   [red,very thick,dashed,->]   (3.8,15.5) -- (4.2,15.5);
# \node  at  (5.5, 15.5) {-8.0};
# \draw   [red,very thick,dashed,->]   (4.8,15.5) -- (5.2,15.5);
# \node  at  (6.5, 15.5) {-10.0};
# \draw   [red,very thick,dashed,->]   (5.8,15.5) -- (6.2,15.5);
# \node  at  (7.5, 15.5) {-12.0};
# \draw   [red,very thick,dashed,->]   (6.8,15.5) -- (7.2,15.5);
# \node  at  (8.5, 15.5) {-14.0};
# \draw   [red,very thick,dashed,->]   (7.8,15.5) -- (8.2,15.5);
# \node  at  (9.5, 15.5) {-16.0};
# \draw   [red,very thick,dashed,->]   (8.8,15.5) -- (9.2,15.5);
# \node  at  (10.5, 15.5) {-18.0};
# \draw   [red,very thick,dashed,->]   (9.8,15.5) -- (10.2,15.5);
# \node  at  (11.5, 15.5) {-20.0};
# \draw   [red,very thick,dashed,->]   (10.8,15.5) -- (11.2,15.5);
# \node  at  (12.5, 15.5) {-22.0};
# \draw   [red,very thick,dashed,->]   (11.8,15.5) -- (12.2,15.5);
# \node  at  (13.5, 15.5) {-24.0};
# \draw   [red,very thick,dashed,->]   (12.8,15.5) -- (13.2,15.5);
# \node  at  (14.5, 15.5) {-26.0};
# \draw   [red,very thick,dashed,->]   (13.8,15.5) -- (14.2,15.5);
# \node  at  (1.5, 14.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (1.5,15.2) -- (1.5,14.8);
# \node  at  (2.5, 14.5) {3.0};
# \draw   [red,very thick,dashed,->]   (1.8,15.2) -- (2.2,14.8);
# \node  at  (3.5, 14.5) {1.0};
# \draw   [red,very thick,dashed,->]   (2.8,14.5) -- (3.2,14.5);
# \node  at  (4.5, 14.5) {-1.0};
# \draw   [red,very thick,dashed,->]   (3.8,14.5) -- (4.2,14.5);
# \node  at  (5.5, 14.5) {-3.0};
# \draw   [red,very thick,dashed,->]   (4.8,15.2) -- (5.2,14.8);
# \draw   [red,very thick,dashed,->]   (4.8,14.5) -- (5.2,14.5);
# \node  at  (6.5, 14.5) {-5.0};
# \draw   [red,very thick,dashed,->]   (5.8,14.5) -- (6.2,14.5);
# \node  at  (7.5, 14.5) {-7.0};
# \draw   [red,very thick,dashed,->]   (6.8,15.2) -- (7.2,14.8);
# \draw   [red,very thick,dashed,->]   (6.8,14.5) -- (7.2,14.5);
# \node  at  (8.5, 14.5) {-9.0};
# \draw   [red,very thick,dashed,->]   (7.8,14.5) -- (8.2,14.5);
# \node  at  (9.5, 14.5) {-11.0};
# \draw   [red,very thick,dashed,->]   (8.8,14.5) -- (9.2,14.5);
# \node  at  (10.5, 14.5) {-13.0};
# \draw   [red,very thick,dashed,->]   (9.8,14.5) -- (10.2,14.5);
# \node  at  (11.5, 14.5) {-15.0};
# \draw   [red,very thick,dashed,->]   (10.8,14.5) -- (11.2,14.5);
# \node  at  (12.5, 14.5) {-17.0};
# \draw   [red,very thick,dashed,->]   (11.8,14.5) -- (12.2,14.5);
# \node  at  (13.5, 14.5) {-19.0};
# \draw   [red,very thick,dashed,->]   (12.8,15.2) -- (13.2,14.8);
# \draw   [red,very thick,dashed,->]   (12.8,14.5) -- (13.2,14.5);
# \node  at  (14.5, 14.5) {-21.0};
# \draw   [red,very thick,dashed,->]   (13.8,14.5) -- (14.2,14.5);
# \node  at  (1.5, 13.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (1.5,14.2) -- (1.5,13.8);
# \node  at  (2.5, 13.5) {1.0};
# \draw   [red,very thick,dashed,->]   (2.5,14.2) -- (2.5,13.8);
# \node  at  (3.5, 13.5) {6.0};
# \draw   [red,very thick,dashed,->]   (2.8,14.2) -- (3.2,13.8);
# \node  at  (4.5, 13.5) {4.0};
# \draw   [red,very thick,dashed,->]   (3.8,13.5) -- (4.2,13.5);
# \node  at  (5.5, 13.5) {2.0};
# \draw   [red,very thick,dashed,->]   (4.8,13.5) -- (5.2,13.5);
# \node  at  (6.5, 13.5) {0.0};
# \draw   [red,very thick,dashed,->]   (5.8,13.5) -- (6.2,13.5);
# \node  at  (7.5, 13.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (6.8,13.5) -- (7.2,13.5);
# \node  at  (8.5, 13.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (7.8,14.2) -- (8.2,13.8);
# \draw   [red,very thick,dashed,->]   (7.8,13.5) -- (8.2,13.5);
# \node  at  (9.5, 13.5) {-6.0};
# \draw   [red,very thick,dashed,->]   (8.8,13.5) -- (9.2,13.5);
# \node  at  (10.5, 13.5) {-8.0};
# \draw   [red,very thick,dashed,->]   (9.8,14.2) -- (10.2,13.8);
# \draw   [red,very thick,dashed,->]   (9.8,13.5) -- (10.2,13.5);
# \node  at  (11.5, 13.5) {-10.0};
# \draw   [red,very thick,dashed,->]   (10.8,14.2) -- (11.2,13.8);
# \draw   [red,very thick,dashed,->]   (10.8,13.5) -- (11.2,13.5);
# \node  at  (12.5, 13.5) {-12.0};
# \draw   [red,very thick,dashed,->]   (11.8,14.2) -- (12.2,13.8);
# \draw   [red,very thick,dashed,->]   (11.8,13.5) -- (12.2,13.5);
# \node  at  (13.5, 13.5) {-14.0};
# \draw   [red,very thick,dashed,->]   (12.8,13.5) -- (13.2,13.5);
# \node  at  (14.5, 13.5) {-16.0};
# \draw   [red,very thick,dashed,->]   (13.8,13.5) -- (14.2,13.5);
# \node  at  (1.5, 12.5) {-6.0};
# \draw   [red,very thick,dashed,->]   (1.5,13.2) -- (1.5,12.8);
# \node  at  (2.5, 12.5) {-1.0};
# \draw   [red,very thick,dashed,->]   (2.5,13.2) -- (2.5,12.8);
# \node  at  (3.5, 12.5) {4.0};
# \draw   [red,very thick,dashed,->]   (3.5,13.2) -- (3.5,12.8);
# \node  at  (4.5, 12.5) {9.0};
# \draw   [red,very thick,dashed,->]   (3.8,13.2) -- (4.2,12.8);
# \node  at  (5.5, 12.5) {7.0};
# \draw   [red,very thick,dashed,->]   (4.8,12.5) -- (5.2,12.5);
# \node  at  (6.5, 12.5) {5.0};
# \draw   [red,very thick,dashed,->]   (5.8,12.5) -- (6.2,12.5);
# \node  at  (7.5, 12.5) {3.0};
# \draw   [red,very thick,dashed,->]   (6.8,12.5) -- (7.2,12.5);
# \node  at  (8.5, 12.5) {1.0};
# \draw   [red,very thick,dashed,->]   (7.8,12.5) -- (8.2,12.5);
# \node  at  (9.5, 12.5) {-1.0};
# \draw   [red,very thick,dashed,->]   (8.8,13.2) -- (9.2,12.8);
# \draw   [red,very thick,dashed,->]   (8.8,12.5) -- (9.2,12.5);
# \node  at  (10.5, 12.5) {-3.0};
# \draw   [red,very thick,dashed,->]   (9.8,12.5) -- (10.2,12.5);
# \node  at  (11.5, 12.5) {-5.0};
# \draw   [red,very thick,dashed,->]   (10.8,12.5) -- (11.2,12.5);
# \node  at  (12.5, 12.5) {-7.0};
# \draw   [red,very thick,dashed,->]   (11.8,12.5) -- (12.2,12.5);
# \node  at  (13.5, 12.5) {-9.0};
# \draw   [red,very thick,dashed,->]   (12.8,12.5) -- (13.2,12.5);
# \node  at  (14.5, 12.5) {-11.0};
# \draw   [red,very thick,dashed,->]   (13.8,13.2) -- (14.2,12.8);
# \draw   [red,very thick,dashed,->]   (13.8,12.5) -- (14.2,12.5);
# \node  at  (1.5, 11.5) {-8.0};
# \draw   [red,very thick,dashed,->]   (1.5,12.2) -- (1.5,11.8);
# \node  at  (2.5, 11.5) {-3.0};
# \draw   [red,very thick,dashed,->]   (2.5,12.2) -- (2.5,11.8);
# \node  at  (3.5, 11.5) {2.0};
# \draw   [red,very thick,dashed,->]   (2.8,12.2) -- (3.2,11.8);
# \draw   [red,very thick,dashed,->]   (3.5,12.2) -- (3.5,11.8);
# \node  at  (4.5, 11.5) {7.0};
# \draw   [red,very thick,dashed,->]   (4.5,12.2) -- (4.5,11.8);
# \node  at  (5.5, 11.5) {8.0};
# \draw   [red,very thick,dashed,->]   (4.8,12.2) -- (5.2,11.8);
# \node  at  (6.5, 11.5) {6.0};
# \draw   [red,very thick,dashed,->]   (5.8,12.2) -- (6.2,11.8);
# \draw   [red,very thick,dashed,->]   (5.8,11.5) -- (6.2,11.5);
# \node  at  (7.5, 11.5) {4.0};
# \draw   [red,very thick,dashed,->]   (6.8,12.2) -- (7.2,11.8);
# \draw   [red,very thick,dashed,->]   (6.8,11.5) -- (7.2,11.5);
# \node  at  (8.5, 11.5) {6.0};
# \draw   [red,very thick,dashed,->]   (7.8,12.2) -- (8.2,11.8);
# \node  at  (9.5, 11.5) {4.0};
# \draw   [red,very thick,dashed,->]   (8.8,11.5) -- (9.2,11.5);
# \node  at  (10.5, 11.5) {2.0};
# \draw   [red,very thick,dashed,->]   (9.8,12.2) -- (10.2,11.8);
# \draw   [red,very thick,dashed,->]   (9.8,11.5) -- (10.2,11.5);
# \node  at  (11.5, 11.5) {0.0};
# \draw   [red,very thick,dashed,->]   (10.8,12.2) -- (11.2,11.8);
# \draw   [red,very thick,dashed,->]   (10.8,11.5) -- (11.2,11.5);
# \node  at  (12.5, 11.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (11.8,12.2) -- (12.2,11.8);
# \draw   [red,very thick,dashed,->]   (11.8,11.5) -- (12.2,11.5);
# \node  at  (13.5, 11.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (12.8,11.5) -- (13.2,11.5);
# \node  at  (14.5, 11.5) {-6.0};
# \draw   [red,very thick,dashed,->]   (13.8,11.5) -- (14.2,11.5);
# \node  at  (1.5, 10.5) {-10.0};
# \draw   [red,very thick,dashed,->]   (1.5,11.2) -- (1.5,10.8);
# \node  at  (2.5, 10.5) {-5.0};
# \draw   [red,very thick,dashed,->]   (1.8,11.2) -- (2.2,10.8);
# \draw   [red,very thick,dashed,->]   (2.5,11.2) -- (2.5,10.8);
# \node  at  (3.5, 10.5) {0.0};
# \draw   [red,very thick,dashed,->]   (3.5,11.2) -- (3.5,10.8);
# \node  at  (4.5, 10.5) {5.0};
# \draw   [red,very thick,dashed,->]   (4.5,11.2) -- (4.5,10.8);
# \node  at  (5.5, 10.5) {10.0};
# \draw   [red,very thick,dashed,->]   (4.8,11.2) -- (5.2,10.8);
# \node  at  (6.5, 10.5) {8.0};
# \draw   [red,very thick,dashed,->]   (5.8,10.5) -- (6.2,10.5);
# \node  at  (7.5, 10.5) {9.0};
# \draw   [red,very thick,dashed,->]   (6.8,11.2) -- (7.2,10.8);
# \node  at  (8.5, 10.5) {7.0};
# \draw   [red,very thick,dashed,->]   (7.8,10.5) -- (8.2,10.5);
# \node  at  (9.5, 10.5) {5.0};
# \draw   [red,very thick,dashed,->]   (8.8,11.2) -- (9.2,10.8);
# \draw   [red,very thick,dashed,->]   (8.8,10.5) -- (9.2,10.5);
# \node  at  (10.5, 10.5) {3.0};
# \draw   [red,very thick,dashed,->]   (9.8,11.2) -- (10.2,10.8);
# \draw   [red,very thick,dashed,->]   (9.8,10.5) -- (10.2,10.5);
# \node  at  (11.5, 10.5) {1.0};
# \draw   [red,very thick,dashed,->]   (10.8,11.2) -- (11.2,10.8);
# \draw   [red,very thick,dashed,->]   (10.8,10.5) -- (11.2,10.5);
# \node  at  (12.5, 10.5) {-1.0};
# \draw   [red,very thick,dashed,->]   (11.8,11.2) -- (12.2,10.8);
# \draw   [red,very thick,dashed,->]   (11.8,10.5) -- (12.2,10.5);
# \node  at  (13.5, 10.5) {1.0};
# \draw   [red,very thick,dashed,->]   (12.8,11.2) -- (13.2,10.8);
# \node  at  (14.5, 10.5) {-1.0};
# \draw   [red,very thick,dashed,->]   (13.8,10.5) -- (14.2,10.5);
# \node  at  (1.5, 9.5) {-12.0};
# \draw   [red,very thick,dashed,->]   (1.5,10.2) -- (1.5,9.8);
# \node  at  (2.5, 9.5) {-7.0};
# \draw   [red,very thick,dashed,->]   (2.5,10.2) -- (2.5,9.8);
# \node  at  (3.5, 9.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (2.8,10.2) -- (3.2,9.8);
# \draw   [red,very thick,dashed,->]   (3.5,10.2) -- (3.5,9.8);
# \node  at  (4.5, 9.5) {3.0};
# \draw   [red,very thick,dashed,->]   (4.5,10.2) -- (4.5,9.8);
# \node  at  (5.5, 9.5) {8.0};
# \draw   [red,very thick,dashed,->]   (5.5,10.2) -- (5.5,9.8);
# \node  at  (6.5, 9.5) {9.0};
# \draw   [red,very thick,dashed,->]   (5.8,10.2) -- (6.2,9.8);
# \node  at  (7.5, 9.5) {7.0};
# \draw   [red,very thick,dashed,->]   (6.8,10.2) -- (7.2,9.8);
# \draw   [red,very thick,dashed,->]   (7.5,10.2) -- (7.5,9.8);
# \draw   [red,very thick,dashed,->]   (6.8,9.5) -- (7.2,9.5);
# \node  at  (8.5, 9.5) {12.0};
# \draw   [red,very thick,dashed,->]   (7.8,10.2) -- (8.2,9.8);
# \node  at  (9.5, 9.5) {10.0};
# \draw   [red,very thick,dashed,->]   (8.8,9.5) -- (9.2,9.5);
# \node  at  (10.5, 9.5) {8.0};
# \draw   [red,very thick,dashed,->]   (9.8,10.2) -- (10.2,9.8);
# \draw   [red,very thick,dashed,->]   (9.8,9.5) -- (10.2,9.5);
# \node  at  (11.5, 9.5) {6.0};
# \draw   [red,very thick,dashed,->]   (10.8,10.2) -- (11.2,9.8);
# \draw   [red,very thick,dashed,->]   (10.8,9.5) -- (11.2,9.5);
# \node  at  (12.5, 9.5) {4.0};
# \draw   [red,very thick,dashed,->]   (11.8,10.2) -- (12.2,9.8);
# \draw   [red,very thick,dashed,->]   (11.8,9.5) -- (12.2,9.5);
# \node  at  (13.5, 9.5) {2.0};
# \draw   [red,very thick,dashed,->]   (12.8,9.5) -- (13.2,9.5);
# \node  at  (14.5, 9.5) {0.0};
# \draw   [red,very thick,dashed,->]   (13.8,10.2) -- (14.2,9.8);
# \draw   [red,very thick,dashed,->]   (13.8,9.5) -- (14.2,9.5);
# \node  at  (1.5, 8.5) {-14.0};
# \draw   [red,very thick,dashed,->]   (1.5,9.2) -- (1.5,8.8);
# \node  at  (2.5, 8.5) {-9.0};
# \draw   [red,very thick,dashed,->]   (1.8,9.2) -- (2.2,8.8);
# \draw   [red,very thick,dashed,->]   (2.5,9.2) -- (2.5,8.8);
# \node  at  (3.5, 8.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (3.5,9.2) -- (3.5,8.8);
# \node  at  (4.5, 8.5) {1.0};
# \draw   [red,very thick,dashed,->]   (4.5,9.2) -- (4.5,8.8);
# \node  at  (5.5, 8.5) {6.0};
# \draw   [red,very thick,dashed,->]   (4.8,9.2) -- (5.2,8.8);
# \draw   [red,very thick,dashed,->]   (5.5,9.2) -- (5.5,8.8);
# \node  at  (6.5, 8.5) {7.0};
# \draw   [red,very thick,dashed,->]   (5.8,9.2) -- (6.2,8.8);
# \draw   [red,very thick,dashed,->]   (6.5,9.2) -- (6.5,8.8);
# \node  at  (7.5, 8.5) {12.0};
# \draw   [red,very thick,dashed,->]   (6.8,9.2) -- (7.2,8.8);
# \node  at  (8.5, 8.5) {10.0};
# \draw   [red,very thick,dashed,->]   (8.5,9.2) -- (8.5,8.8);
# \draw   [red,very thick,dashed,->]   (7.8,8.5) -- (8.2,8.5);
# \node  at  (9.5, 8.5) {11.0};
# \draw   [red,very thick,dashed,->]   (8.8,9.2) -- (9.2,8.8);
# \node  at  (10.5, 8.5) {9.0};
# \draw   [red,very thick,dashed,->]   (9.8,9.2) -- (10.2,8.8);
# \draw   [red,very thick,dashed,->]   (9.8,8.5) -- (10.2,8.5);
# \node  at  (11.5, 8.5) {7.0};
# \draw   [red,very thick,dashed,->]   (10.8,9.2) -- (11.2,8.8);
# \draw   [red,very thick,dashed,->]   (10.8,8.5) -- (11.2,8.5);
# \node  at  (12.5, 8.5) {5.0};
# \draw   [red,very thick,dashed,->]   (11.8,9.2) -- (12.2,8.8);
# \draw   [red,very thick,dashed,->]   (11.8,8.5) -- (12.2,8.5);
# \node  at  (13.5, 8.5) {7.0};
# \draw   [red,very thick,dashed,->]   (12.8,9.2) -- (13.2,8.8);
# \node  at  (14.5, 8.5) {5.0};
# \draw   [red,very thick,dashed,->]   (13.8,8.5) -- (14.2,8.5);
# \node  at  (1.5, 7.5) {-16.0};
# \draw   [red,very thick,dashed,->]   (1.5,8.2) -- (1.5,7.8);
# \node  at  (2.5, 7.5) {-11.0};
# \draw   [red,very thick,dashed,->]   (2.5,8.2) -- (2.5,7.8);
# \node  at  (3.5, 7.5) {-6.0};
# \draw   [red,very thick,dashed,->]   (3.5,8.2) -- (3.5,7.8);
# \node  at  (4.5, 7.5) {-1.0};
# \draw   [red,very thick,dashed,->]   (4.5,8.2) -- (4.5,7.8);
# \node  at  (5.5, 7.5) {4.0};
# \draw   [red,very thick,dashed,->]   (5.5,8.2) -- (5.5,7.8);
# \node  at  (6.5, 7.5) {9.0};
# \draw   [red,very thick,dashed,->]   (5.8,8.2) -- (6.2,7.8);
# \node  at  (7.5, 7.5) {10.0};
# \draw   [red,very thick,dashed,->]   (7.5,8.2) -- (7.5,7.8);
# \node  at  (8.5, 7.5) {11.0};
# \draw   [red,very thick,dashed,->]   (7.8,8.2) -- (8.2,7.8);
# \node  at  (9.5, 7.5) {9.0};
# \draw   [red,very thick,dashed,->]   (8.8,8.2) -- (9.2,7.8);
# \draw   [red,very thick,dashed,->]   (9.5,8.2) -- (9.5,7.8);
# \draw   [red,very thick,dashed,->]   (8.8,7.5) -- (9.2,7.5);
# \node  at  (10.5, 7.5) {10.0};
# \draw   [red,very thick,dashed,->]   (9.8,8.2) -- (10.2,7.8);
# \node  at  (11.5, 7.5) {8.0};
# \draw   [red,very thick,dashed,->]   (10.8,8.2) -- (11.2,7.8);
# \draw   [red,very thick,dashed,->]   (10.8,7.5) -- (11.2,7.5);
# \node  at  (12.5, 7.5) {6.0};
# \draw   [red,very thick,dashed,->]   (11.8,8.2) -- (12.2,7.8);
# \draw   [red,very thick,dashed,->]   (11.8,7.5) -- (12.2,7.5);
# \node  at  (13.5, 7.5) {5.0};
# \draw   [red,very thick,dashed,->]   (13.5,8.2) -- (13.5,7.8);
# \node  at  (14.5, 7.5) {6.0};
# \draw   [red,very thick,dashed,->]   (13.8,8.2) -- (14.2,7.8);
# \node  at  (1.5, 6.5) {-18.0};
# \draw   [red,very thick,dashed,->]   (1.5,7.2) -- (1.5,6.8);
# \node  at  (2.5, 6.5) {-13.0};
# \draw   [red,very thick,dashed,->]   (1.8,7.2) -- (2.2,6.8);
# \draw   [red,very thick,dashed,->]   (2.5,7.2) -- (2.5,6.8);
# \node  at  (3.5, 6.5) {-8.0};
# \draw   [red,very thick,dashed,->]   (3.5,7.2) -- (3.5,6.8);
# \node  at  (4.5, 6.5) {-3.0};
# \draw   [red,very thick,dashed,->]   (4.5,7.2) -- (4.5,6.8);
# \node  at  (5.5, 6.5) {2.0};
# \draw   [red,very thick,dashed,->]   (4.8,7.2) -- (5.2,6.8);
# \draw   [red,very thick,dashed,->]   (5.5,7.2) -- (5.5,6.8);
# \node  at  (6.5, 6.5) {7.0};
# \draw   [red,very thick,dashed,->]   (6.5,7.2) -- (6.5,6.8);
# \node  at  (7.5, 6.5) {12.0};
# \draw   [red,very thick,dashed,->]   (6.8,7.2) -- (7.2,6.8);
# \node  at  (8.5, 6.5) {10.0};
# \draw   [red,very thick,dashed,->]   (7.8,6.5) -- (8.2,6.5);
# \node  at  (9.5, 6.5) {10.0};
# \draw   [red,very thick,dashed,->]   (8.8,7.2) -- (9.2,6.8);
# \node  at  (10.5, 6.5) {8.0};
# \draw   [red,very thick,dashed,->]   (9.8,7.2) -- (10.2,6.8);
# \draw   [red,very thick,dashed,->]   (10.5,7.2) -- (10.5,6.8);
# \draw   [red,very thick,dashed,->]   (9.8,6.5) -- (10.2,6.5);
# \node  at  (11.5, 6.5) {9.0};
# \draw   [red,very thick,dashed,->]   (10.8,7.2) -- (11.2,6.8);
# \node  at  (12.5, 6.5) {7.0};
# \draw   [red,very thick,dashed,->]   (11.8,7.2) -- (12.2,6.8);
# \draw   [red,very thick,dashed,->]   (11.8,6.5) -- (12.2,6.5);
# \node  at  (13.5, 6.5) {9.0};
# \draw   [red,very thick,dashed,->]   (12.8,7.2) -- (13.2,6.8);
# \node  at  (14.5, 6.5) {7.0};
# \draw   [red,very thick,dashed,->]   (13.8,6.5) -- (14.2,6.5);
# \node  at  (1.5, 5.5) {-20.0};
# \draw   [red,very thick,dashed,->]   (1.5,6.2) -- (1.5,5.8);
# \node  at  (2.5, 5.5) {-15.0};
# \draw   [red,very thick,dashed,->]   (2.5,6.2) -- (2.5,5.8);
# \node  at  (3.5, 5.5) {-10.0};
# \draw   [red,very thick,dashed,->]   (2.8,6.2) -- (3.2,5.8);
# \draw   [red,very thick,dashed,->]   (3.5,6.2) -- (3.5,5.8);
# \node  at  (4.5, 5.5) {-5.0};
# \draw   [red,very thick,dashed,->]   (4.5,6.2) -- (4.5,5.8);
# \node  at  (5.5, 5.5) {0.0};
# \draw   [red,very thick,dashed,->]   (5.5,6.2) -- (5.5,5.8);
# \node  at  (6.5, 5.5) {5.0};
# \draw   [red,very thick,dashed,->]   (6.5,6.2) -- (6.5,5.8);
# \node  at  (7.5, 5.5) {10.0};
# \draw   [red,very thick,dashed,->]   (7.5,6.2) -- (7.5,5.8);
# \node  at  (8.5, 5.5) {15.0};
# \draw   [red,very thick,dashed,->]   (7.8,6.2) -- (8.2,5.8);
# \node  at  (9.5, 5.5) {13.0};
# \draw   [red,very thick,dashed,->]   (8.8,5.5) -- (9.2,5.5);
# \node  at  (10.5, 5.5) {13.0};
# \draw   [red,very thick,dashed,->]   (9.8,6.2) -- (10.2,5.8);
# \node  at  (11.5, 5.5) {11.0};
# \draw   [red,very thick,dashed,->]   (10.8,6.2) -- (11.2,5.8);
# \draw   [red,very thick,dashed,->]   (10.8,5.5) -- (11.2,5.5);
# \node  at  (12.5, 5.5) {12.0};
# \draw   [red,very thick,dashed,->]   (11.8,6.2) -- (12.2,5.8);
# \node  at  (13.5, 5.5) {10.0};
# \draw   [red,very thick,dashed,->]   (12.8,5.5) -- (13.2,5.5);
# \node  at  (14.5, 5.5) {8.0};
# \draw   [red,very thick,dashed,->]   (13.8,6.2) -- (14.2,5.8);
# \draw   [red,very thick,dashed,->]   (13.8,5.5) -- (14.2,5.5);
# \node  at  (1.5, 4.5) {-22.0};
# \draw   [red,very thick,dashed,->]   (1.5,5.2) -- (1.5,4.8);
# \node  at  (2.5, 4.5) {-17.0};
# \draw   [red,very thick,dashed,->]   (2.5,5.2) -- (2.5,4.8);
# \node  at  (3.5, 4.5) {-12.0};
# \draw   [red,very thick,dashed,->]   (3.5,5.2) -- (3.5,4.8);
# \node  at  (4.5, 4.5) {-7.0};
# \draw   [red,very thick,dashed,->]   (3.8,5.2) -- (4.2,4.8);
# \draw   [red,very thick,dashed,->]   (4.5,5.2) -- (4.5,4.8);
# \node  at  (5.5, 4.5) {-2.0};
# \draw   [red,very thick,dashed,->]   (5.5,5.2) -- (5.5,4.8);
# \node  at  (6.5, 4.5) {3.0};
# \draw   [red,very thick,dashed,->]   (6.5,5.2) -- (6.5,4.8);
# \node  at  (7.5, 4.5) {8.0};
# \draw   [red,very thick,dashed,->]   (7.5,5.2) -- (7.5,4.8);
# \node  at  (8.5, 4.5) {13.0};
# \draw   [red,very thick,dashed,->]   (8.5,5.2) -- (8.5,4.8);
# \node  at  (9.5, 4.5) {18.0};
# \draw   [red,very thick,dashed,->]   (8.8,5.2) -- (9.2,4.8);
# \node  at  (10.5, 4.5) {16.0};
# \draw   [red,very thick,dashed,->]   (9.8,4.5) -- (10.2,4.5);
# \node  at  (11.5, 4.5) {14.0};
# \draw   [red,very thick,dashed,->]   (10.8,4.5) -- (11.2,4.5);
# \node  at  (12.5, 4.5) {12.0};
# \draw   [red,very thick,dashed,->]   (11.8,4.5) -- (12.2,4.5);
# \node  at  (13.5, 4.5) {11.0};
# \draw   [red,very thick,dashed,->]   (12.8,5.2) -- (13.2,4.8);
# \node  at  (14.5, 4.5) {13.0};
# \draw   [red,very thick,dashed,->]   (13.8,5.2) -- (14.2,4.8);
# \node  at  (1.5, 3.5) {-24.0};
# \draw   [red,very thick,dashed,->]   (1.5,4.2) -- (1.5,3.8);
# \node  at  (2.5, 3.5) {-19.0};
# \draw   [red,very thick,dashed,->]   (2.5,4.2) -- (2.5,3.8);
# \node  at  (3.5, 3.5) {-14.0};
# \draw   [red,very thick,dashed,->]   (2.8,4.2) -- (3.2,3.8);
# \draw   [red,very thick,dashed,->]   (3.5,4.2) -- (3.5,3.8);
# \node  at  (4.5, 3.5) {-9.0};
# \draw   [red,very thick,dashed,->]   (4.5,4.2) -- (4.5,3.8);
# \node  at  (5.5, 3.5) {-4.0};
# \draw   [red,very thick,dashed,->]   (5.5,4.2) -- (5.5,3.8);
# \node  at  (6.5, 3.5) {1.0};
# \draw   [red,very thick,dashed,->]   (6.5,4.2) -- (6.5,3.8);
# \node  at  (7.5, 3.5) {6.0};
# \draw   [red,very thick,dashed,->]   (7.5,4.2) -- (7.5,3.8);
# \node  at  (8.5, 3.5) {11.0};
# \draw   [red,very thick,dashed,->]   (7.8,4.2) -- (8.2,3.8);
# \draw   [red,very thick,dashed,->]   (8.5,4.2) -- (8.5,3.8);
# \node  at  (9.5, 3.5) {16.0};
# \draw   [red,very thick,dashed,->]   (9.5,4.2) -- (9.5,3.8);
# \node  at  (10.5, 3.5) {21.0};
# \draw   [red,very thick,dashed,->]   (9.8,4.2) -- (10.2,3.8);
# \node  at  (11.5, 3.5) {19.0};
# \draw   [red,very thick,dashed,->]   (10.8,4.2) -- (11.2,3.8);
# \draw   [red,very thick,dashed,->]   (10.8,3.5) -- (11.2,3.5);
# \node  at  (12.5, 3.5) {17.0};
# \draw   [red,very thick,dashed,->]   (11.8,4.2) -- (12.2,3.8);
# \draw   [red,very thick,dashed,->]   (11.8,3.5) -- (12.2,3.5);
# \node  at  (13.5, 3.5) {15.0};
# \draw   [red,very thick,dashed,->]   (12.8,3.5) -- (13.2,3.5);
# \node  at  (14.5, 3.5) {13.0};
# \draw   [red,very thick,dashed,->]   (13.8,3.5) -- (14.2,3.5);
# \node  at  (1.5, 2.5) {-26.0};
# \draw   [red,very thick,dashed,->]   (1.5,3.2) -- (1.5,2.8);
# \node  at  (2.5, 2.5) {-21.0};
# \draw   [red,very thick,dashed,->]   (1.8,3.2) -- (2.2,2.8);
# \draw   [red,very thick,dashed,->]   (2.5,3.2) -- (2.5,2.8);
# \node  at  (3.5, 2.5) {-16.0};
# \draw   [red,very thick,dashed,->]   (3.5,3.2) -- (3.5,2.8);
# \node  at  (4.5, 2.5) {-11.0};
# \draw   [red,very thick,dashed,->]   (4.5,3.2) -- (4.5,2.8);
# \node  at  (5.5, 2.5) {-6.0};
# \draw   [red,very thick,dashed,->]   (4.8,3.2) -- (5.2,2.8);
# \draw   [red,very thick,dashed,->]   (5.5,3.2) -- (5.5,2.8);
# \node  at  (6.5, 2.5) {-1.0};
# \draw   [red,very thick,dashed,->]   (6.5,3.2) -- (6.5,2.8);
# \node  at  (7.5, 2.5) {4.0};
# \draw   [red,very thick,dashed,->]   (6.8,3.2) -- (7.2,2.8);
# \draw   [red,very thick,dashed,->]   (7.5,3.2) -- (7.5,2.8);
# \node  at  (8.5, 2.5) {9.0};
# \draw   [red,very thick,dashed,->]   (8.5,3.2) -- (8.5,2.8);
# \node  at  (9.5, 2.5) {14.0};
# \draw   [red,very thick,dashed,->]   (9.5,3.2) -- (9.5,2.8);
# \node  at  (10.5, 2.5) {19.0};
# \draw   [red,very thick,dashed,->]   (10.5,3.2) -- (10.5,2.8);
# \node  at  (11.5, 2.5) {20.0};
# \draw   [red,very thick,dashed,->]   (10.8,3.2) -- (11.2,2.8);
# \node  at  (12.5, 2.5) {18.0};
# \draw   [red,very thick,dashed,->]   (11.8,3.2) -- (12.2,2.8);
# \draw   [red,very thick,dashed,->]   (11.8,2.5) -- (12.2,2.5);
# \node  at  (13.5, 2.5) {20.0};
# \draw   [red,very thick,dashed,->]   (12.8,3.2) -- (13.2,2.8);
# \node  at  (14.5, 2.5) {18.0};
# \draw   [red,very thick,dashed,->]   (13.8,2.5) -- (14.2,2.5);
# \node  at  (1.5, 1.5) {-28.0};
# \draw   [red,very thick,dashed,->]   (1.5,2.2) -- (1.5,1.8);
# \node  at  (2.5, 1.5) {-23.0};
# \draw   [red,very thick,dashed,->]   (1.8,2.2) -- (2.2,1.8);
# \draw   [red,very thick,dashed,->]   (2.5,2.2) -- (2.5,1.8);
# \node  at  (3.5, 1.5) {-18.0};
# \draw   [red,very thick,dashed,->]   (3.5,2.2) -- (3.5,1.8);
# \node  at  (4.5, 1.5) {-13.0};
# \draw   [red,very thick,dashed,->]   (4.5,2.2) -- (4.5,1.8);
# \node  at  (5.5, 1.5) {-8.0};
# \draw   [red,very thick,dashed,->]   (4.8,2.2) -- (5.2,1.8);
# \draw   [red,very thick,dashed,->]   (5.5,2.2) -- (5.5,1.8);
# \node  at  (6.5, 1.5) {-3.0};
# \draw   [red,very thick,dashed,->]   (6.5,2.2) -- (6.5,1.8);
# \node  at  (7.5, 1.5) {2.0};
# \draw   [red,very thick,dashed,->]   (6.8,2.2) -- (7.2,1.8);
# \draw   [red,very thick,dashed,->]   (7.5,2.2) -- (7.5,1.8);
# \node  at  (8.5, 1.5) {7.0};
# \draw   [red,very thick,dashed,->]   (8.5,2.2) -- (8.5,1.8);
# \node  at  (9.5, 1.5) {12.0};
# \draw   [red,very thick,dashed,->]   (9.5,2.2) -- (9.5,1.8);
# \node  at  (10.5, 1.5) {17.0};
# \draw   [red,very thick,dashed,->]   (10.5,2.2) -- (10.5,1.8);
# \node  at  (11.5, 1.5) {18.0};
# \draw   [red,very thick,dashed,->]   (10.8,2.2) -- (11.2,1.8);
# \draw   [red,very thick,dashed,->]   (11.5,2.2) -- (11.5,1.8);
# \node  at  (12.5, 1.5) {19.0};
# \draw   [red,very thick,dashed,->]   (11.8,2.2) -- (12.2,1.8);
# \node  at  (13.5, 1.5) {21.0};
# \draw   [red,very thick,dashed,->]   (12.8,2.2) -- (13.2,1.8);
# \node  at  (14.5, 1.5) {19.0};
# \draw   [red,very thick,dashed,->]   (13.8,2.2) -- (14.2,1.8);
# \draw   [red,very thick,dashed,->]   (13.8,1.5) -- (14.2,1.5);
# \node  at  (1.5, 0.5) {-30.0};
# \draw   [red,very thick,dashed,->]   (1.5,1.2) -- (1.5,0.8);
# \node  at  (2.5, 0.5) {-25.0};
# \draw   [red,very thick,dashed,->]   (2.5,1.2) -- (2.5,0.8);
# \node  at  (3.5, 0.5) {-20.0};
# \draw   [red,very thick,dashed,->]   (3.5,1.2) -- (3.5,0.8);
# \node  at  (4.5, 0.5) {-15.0};
# \draw   [red,very thick,dashed,->]   (3.8,1.2) -- (4.2,0.8);
# \draw   [red,very thick,dashed,->]   (4.5,1.2) -- (4.5,0.8);
# \node  at  (5.5, 0.5) {-10.0};
# \draw   [red,very thick,dashed,->]   (5.5,1.2) -- (5.5,0.8);
# \node  at  (6.5, 0.5) {-5.0};
# \draw   [red,very thick,dashed,->]   (6.5,1.2) -- (6.5,0.8);
# \node  at  (7.5, 0.5) {0.0};
# \draw   [red,very thick,dashed,->]   (7.5,1.2) -- (7.5,0.8);
# \node  at  (8.5, 0.5) {5.0};
# \draw   [red,very thick,dashed,->]   (8.5,1.2) -- (8.5,0.8);
# \node  at  (9.5, 0.5) {10.0};
# \draw   [red,very thick,dashed,->]   (8.8,1.2) -- (9.2,0.8);
# \draw   [red,very thick,dashed,->]   (9.5,1.2) -- (9.5,0.8);
# \node  at  (10.5, 0.5) {15.0};
# \draw   [red,very thick,dashed,->]   (10.5,1.2) -- (10.5,0.8);
# \node  at  (11.5, 0.5) {16.0};
# \draw   [red,very thick,dashed,->]   (10.8,1.2) -- (11.2,0.8);
# \draw   [red,very thick,dashed,->]   (11.5,1.2) -- (11.5,0.8);
# \node  at  (12.5, 0.5) {17.0};
# \draw   [red,very thick,dashed,->]   (11.8,1.2) -- (12.2,0.8);
# \draw   [red,very thick,dashed,->]   (12.5,1.2) -- (12.5,0.8);
# \node  at  (13.5, 0.5) {19.0};
# \draw   [red,very thick,dashed,->]   (13.5,1.2) -- (13.5,0.8);
# \node  at  (14.5, 0.5) {24.0};
# \draw   [red,very thick,dashed,->]   (13.8,1.2) -- (14.2,0.8);
# \draw [blue,very thick,->] (14.3,0.8) -- (13.9,1.2);
# \draw [blue,very thick,->] (13.3,1.8) -- (12.9,2.2);
# \draw [blue,very thick,->] (12.3,2.8) -- (11.9,3.2);
# \draw [blue,very thick,->] (11.3,3.8) -- (10.9,4.2);
# \draw [blue,very thick,->] (10.2,4.6) -- (9.8,4.6);
# \draw [blue,very thick,->] (9.3,4.8) -- (8.9,5.2);
# \draw [blue,very thick,->] (8.3,5.8) -- (7.9,6.2);
# \draw [blue,very thick,->] (7.3,6.8) -- (6.9,7.2);
# \draw [blue,very thick,->] (6.3,7.8) -- (5.9,8.2);
# \draw [blue,very thick,->] (5.3,8.8) -- (4.9,9.2);
# \draw [blue,very thick,->] (4.6,9.8) -- (4.6,10.2);
# \draw [blue,very thick,->] (4.6,10.8) -- (4.6,11.2);
# \draw [blue,very thick,->] (4.6,11.8) -- (4.6,12.2);
# \draw [blue,very thick,->] (4.3,12.8) -- (3.9,13.2);
# \draw [blue,very thick,->] (3.3,13.8) -- (2.9,14.2);
# \draw [blue,very thick,->] (2.3,14.8) -- (1.9,15.2);
# \draw [blue,very thick,->] (5.6,8.8) -- (5.6,9.2);
# \draw [blue,very thick,->] (5.6,9.8) -- (5.6,10.2);
# \draw [blue,very thick,->] (5.3,10.8) -- (4.9,11.2);
# \draw [blue,very thick,->] (4.6,11.8) -- (4.6,12.2);
# \draw [blue,very thick,->] (4.3,12.8) -- (3.9,13.2);
# \draw [blue,very thick,->] (3.3,13.8) -- (2.9,14.2);
# \draw [blue,very thick,->] (2.3,14.8) -- (1.9,15.2);
# \draw [blue,very thick,->] (11.2,3.6) -- (10.8,3.6);
# \draw [blue,very thick,->] (10.3,3.8) -- (9.9,4.2);
# \draw [blue,very thick,->] (9.3,4.8) -- (8.9,5.2);
# \draw [blue,very thick,->] (8.3,5.8) -- (7.9,6.2);
# \draw [blue,very thick,->] (7.3,6.8) -- (6.9,7.2);
# \draw [blue,very thick,->] (6.3,7.8) -- (5.9,8.2);
# \draw [blue,very thick,->] (5.3,8.8) -- (4.9,9.2);
# \draw [blue,very thick,->] (4.6,9.8) -- (4.6,10.2);
# \draw [blue,very thick,->] (4.6,10.8) -- (4.6,11.2);
# \draw [blue,very thick,->] (4.6,11.8) -- (4.6,12.2);
# \draw [blue,very thick,->] (4.3,12.8) -- (3.9,13.2);
# \draw [blue,very thick,->] (3.3,13.8) -- (2.9,14.2);
# \draw [blue,very thick,->] (2.3,14.8) -- (1.9,15.2);
# \draw [blue,very thick,->] (5.6,8.8) -- (5.6,9.2);
# \draw [blue,very thick,->] (5.6,9.8) -- (5.6,10.2);
# \draw [blue,very thick,->] (5.3,10.8) -- (4.9,11.2);
# \draw [blue,very thick,->] (4.6,11.8) -- (4.6,12.2);
# \draw [blue,very thick,->] (4.3,12.8) -- (3.9,13.2);
# \draw [blue,very thick,->] (3.3,13.8) -- (2.9,14.2);
# \draw [blue,very thick,->] (2.3,14.8) -- (1.9,15.2);
# \draw [blue,very thick,->] (12.2,2.6) -- (11.8,2.6);
# \draw [blue,very thick,->] (11.3,2.8) -- (10.9,3.2);
# \draw [blue,very thick,->] (10.3,3.8) -- (9.9,4.2);
# \draw [blue,very thick,->] (9.3,4.8) -- (8.9,5.2);
# \draw [blue,very thick,->] (8.3,5.8) -- (7.9,6.2);
# \draw [blue,very thick,->] (7.3,6.8) -- (6.9,7.2);
# \draw [blue,very thick,->] (6.3,7.8) -- (5.9,8.2);
# \draw [blue,very thick,->] (5.3,8.8) -- (4.9,9.2);
# \draw [blue,very thick,->] (4.6,9.8) -- (4.6,10.2);
# \draw [blue,very thick,->] (4.6,10.8) -- (4.6,11.2);
# \draw [blue,very thick,->] (4.6,11.8) -- (4.6,12.2);
# \draw [blue,very thick,->] (4.3,12.8) -- (3.9,13.2);
# \draw [blue,very thick,->] (3.3,13.8) -- (2.9,14.2);
# \draw [blue,very thick,->] (2.3,14.8) -- (1.9,15.2);
# \draw [blue,very thick,->] (5.6,8.8) -- (5.6,9.2);
# \draw [blue,very thick,->] (5.6,9.8) -- (5.6,10.2);
# \draw [blue,very thick,->] (5.3,10.8) -- (4.9,11.2);
# \draw [blue,very thick,->] (4.6,11.8) -- (4.6,12.2);
# \draw [blue,very thick,->] (4.3,12.8) -- (3.9,13.2);
# \draw [blue,very thick,->] (3.3,13.8) -- (2.9,14.2);
# \draw [blue,very thick,->] (2.3,14.8) -- (1.9,15.2);
# \end{tikzpicture}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 seqA,seqB = global_align("CTATCTCGCTATCCA","CTACGCTATTTCA",True)
#       2 print_alignment(seqA,seqB)
#
# TypeError: cannot unpack non-iterable NoneType object
